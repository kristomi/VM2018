# %% [markdown]
# # Statistical model

# %% [markdown]
# Importerer pakker

# %%
import json
import requests
import pickle
import math
import pandas as pd
import os
import numpy as np
import collections
from pathlib import Path
import pymc3 as pm
import theano.tensor as tt
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

import menon_styles
# %load_ext autoreload
# %autoreload 2

ROOT_DIR = Path(os.environ.get('ROOT_DIR'))
DATA_DIR = ROOT_DIR / 'data'


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('float_format', '{:.2f}'.format)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Menon-farger

# %%
menon_styles.menon_styles()
# Out:
# <style>
# html {
#   font-size: 62.5% !important;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
# }
# tr:nth-child(2) tr:hover {
#   background: yellow;
# }
#
# div.text_cell_render {
#     font-family: Calibri, sans-serif !important;
#     font-size: 10pt;
# }
# .text_cell.rendered h1, h2, h3, h4 {
#   font-family: Calibri, sans-serif !important;
# 	margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: bold !important; }
# .text_cell.rendered h1 {
#   font-size: 30pt;
# }
# .text_cell.rendered h2 {
# 	font-size: 24pt;
#   color: rgb(57,87,117);
# }
# .text_cell.rendered h3 {
# 	font-size: 20pt;
#   color: rgb(214,127,22);
# }
# .text_cell.rendered h4 {
# 	font-size: 14pt;
#   color: rgb(57,87,117);
# }
# </style>
#
#
# <style>
# h1:after {
#     content: url('https://www.menon.no/wp-content/uploads/2017logo@2x.png');
#     float: right;
# }
# </style>

# %% [markdown]
# ## Read data

# %%
from src.make_data import make_all
make_all()

# %%
teams = pd.read_pickle(DATA_DIR / 'processed/all_teams.pkl')
teams.head()
# Out:
#    team_idx            team  games    win
# 0         0     Afghanistan    103  29.00
# 1         1         Albania    314  78.00
# 2         2         Algeria    482 202.00
# 3         3  American Samoa     42   4.00
# 4         4         Andorra    146   5.00

# %%
df = (pd
      .read_pickle(DATA_DIR / 'processed/raw.pkl')
      .merge(right=teams[['team', 'team_idx']], left_on='home_team', right_on='team')
      .drop('team', axis=1)
      .rename(columns={'team_idx': 'home_team_idx'})
      .merge(right=teams[['team', 'team_idx']], left_on='away_team', right_on='team')
      .drop('team', axis=1)
      .rename(columns={'team_idx': 'away_team_idx'})
      .assign(year=lambda df: df.date.dt.year - df.date.dt.year.min())
     )
df.to_pickle('../data/games_idx.pkl')
df.head()
# Out:
#         date home_team away_team  home_score  away_score tournament     city  \
# 0 1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1 1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 2 1876-03-04  Scotland   England           3           0   Friendly  Glasgow
# 3 1878-03-02  Scotland   England           7           2   Friendly  Glasgow
# 4 1880-03-13  Scotland   England           5           4   Friendly  Glasgow
#
#     country  neutral  total_goals  abs_goal_diff  home_win  away_win  \
# 0  Scotland    False            0              0     False     False
# 1  Scotland    False            3              1      True     False
# 2  Scotland    False            3              3      True     False
# 3  Scotland    False            9              5      True     False
# 4  Scotland    False            9              1      True     False
#
#    home_team_idx  away_team_idx  year
# 0            181             64     0
# 1            181             64     2
# 2            181             64     4
# 3            181             64     6
# 4            181             64     8

# %%
n_teams = len(teams)
n_teams
# Out:
# 245

# %% [markdown]
# ## Model

# %% [markdown]
# ### Time-varying coefficients on simulated data

# %% [markdown]
# Dette er litt vanskelig, jobber meg gradvis fremover

# %%
included_teams = ['England']
df_tmv = (df
          .copy()
          .query("date.dt.year >= 1980")
          .query("home_team in @included_teams")
          .assign(year = lambda df: df.date.dt.year - df.date.dt.year.min())
          .assign(home_team_idx = lambda df: df.home_team.apply(lambda team: included_teams.index(team)))
          .sort_values(by='date', ascending=True)
         )
df_tmv
# Out:
#             date home_team         away_team  home_score  away_score  \
# 7325  1980-02-06   England           Ireland           2           0
# 10829 1980-05-13   England         Argentina           3           1
# 915   1980-05-20   England  Northern Ireland           1           1
# 5101  1980-09-10   England            Norway           4           0
# 3222  1980-11-19   England       Switzerland           2           1
# 6591  1981-03-25   England             Spain           1           2
# 10111 1981-04-29   England           Romania           0           0
# 8684  1981-05-12   England            Brazil           0           1
# 594   1981-05-20   England             Wales           0           0
# 17457 1981-05-23   England          Scotland           0           1
# 2406  1981-11-18   England           Hungary           1           0
# 916   1982-02-23   England  Northern Ireland           4           0
# 8329  1982-05-25   England       Netherlands           2           0
# 3602  1982-06-16   England            France           3           1
# 2138  1982-06-20   England    Czechoslovakia           2           0
# 18142 1982-06-25   England            Kuwait           1           0
# 1709  1982-10-13   England           Germany           1           2
# 12073 1982-12-15   England        Luxembourg           9           0
# 595   1983-02-23   England             Wales           2           1
# 13675 1983-03-30   England            Greece           0           0
# 2407  1983-04-27   England           Hungary           2           0
# 17458 1983-06-01   England          Scotland           2           0
# 3946  1983-09-21   England           Denmark           0           1
# 917   1984-04-04   England  Northern Ireland           1           0
# 9088  1984-06-02   England            Russia           0           2
# 9944  1984-09-12   England         German DR           1           0
# 7572  1984-10-17   England           Finland           5           0
# 7326  1985-03-26   England           Ireland           2           1
# 7980  1985-06-06   England             Italy           1           2
# 1710  1985-06-12   England           Germany           3           0
# ...          ...       ...               ...         ...         ...
# 21279 2013-10-11   England        Montenegro           4           1
# 6912  2013-10-15   England            Poland           2           0
# 12518 2013-11-15   England             Chile           0           2
# 1717  2013-11-19   England           Germany           0           1
# 3951  2014-03-05   England           Denmark           1           0
# 9614  2014-05-30   England              Peru           3           0
# 7987  2014-06-14   England             Italy           1           2
# 5104  2014-09-03   England            Norway           1           0
# 13116 2014-10-09   England        San Marino           5           0
# 15910 2014-11-15   England          Slovenia           3           1
# 14753 2015-03-27   England         Lithuania           4           0
# 3228  2015-09-08   England       Switzerland           2           0
# 13356 2015-10-09   England           Estonia           2           0
# 3606  2015-11-17   England            France           2           0
# 8338  2016-03-29   England       Netherlands           1           2
# 18377 2016-05-22   England            Turkey           2           1
# 11862 2016-05-27   England         Australia           2           1
# 6031  2016-06-02   England          Portugal           1           0
# 9092  2016-06-11   England            Russia           1           1
# 598   2016-06-16   England             Wales           2           1
# 11636 2016-06-27   England           Iceland           1           2
# 13186 2016-10-08   England             Malta           2           0
# 17464 2016-11-11   England          Scotland           3           0
# 6596  2016-11-15   England             Spain           2           2
# 14754 2017-03-26   England         Lithuania           2           0
# 16978 2017-09-04   England          Slovakia           2           1
# 15911 2017-10-05   England          Slovenia           1           0
# 1718  2017-11-10   England           Germany           0           0
# 8694  2017-11-14   England            Brazil           0           0
# 7988  2018-03-27   England             Italy           1           1
# 595              3              1      True     False              0
# 13675            0              0     False     False              0
# 2407             2              2      True     False              0
# 17458            2              2      True     False              0
# 3946             1              1     False      True              0
# 917              1              1      True     False              0
# 9088             2              2     False      True              0
# 9944             1              1      True     False              0
# 7572             5              5      True     False              0
# 7326             3              1      True     False              0
# 7980             3              1     False      True              0
# 1710             3              3      True     False              0
# ...            ...            ...       ...       ...            ...
# 21279            5              3      True     False              0
# 6912             2              2      True     False              0
# 12518            2              2     False      True              0
# 1717             1              1     False      True              0
# 3951             1              1      True     False              0
# 9614             3              3      True     False              0
# 7987             3              1     False      True              0
# 5104             1              1      True     False              0
# 13116            5              5      True     False              0
# 15910            4              2      True     False              0
# 14753            4              4      True     False              0
# 3228             2              2      True     False              0
# 13356            2              2      True     False              0
# 3606             2              2      True     False              0
# 8338             3              1     False      True              0
# 18377            3              1      True     False              0
# 11862            3              1      True     False              0
# 6031             1              1      True     False              0
# 9092             2              0     False     False              0
# 598              3              1      True     False              0
# 11636            3              1     False      True              0
# 13186            2              2      True     False              0
# 17464            3              3      True     False              0
# 6596             4              0     False     False              0
# 14754            2              2      True     False              0
# 16978            3              1      True     False              0
# 15911            1              1      True     False              0
# 1718             0              0     False     False              0
# 8694             0              0     False     False              0
# 7988             2              0     False     False              0
#
#        away_team_idx  year
# 7325             100     0
# 10829              8     0
# 915              157     0
# 5101             159     0
# 3222             207     0
# 6591             195     1
# 10111            173     1
# 8684              28     1
# 594              236     1
# 17457            181     1
# 2406              94     1
# 916              157     2
# 8329             148     2
# 3602              72     2
# 2138              55     2
# 18142            113     2
# 1709              78     2
# 12073            123     2
# 595              236     3
# 13675             81     3
# 2407              94     3
# 17458            181     3
# 3946              56     3
# 917              157     4
# 9088             174     4
# 9944              77     4
# 7572              71     4
# 7326             100     5
# 7980             102     5
# 1710              78     5
# ...              ...   ...
# 21279            142    33
# 6912             169    33
# 12518             42    33
# 1717              78    33
# 3951              56    34
# 9614             167    34
# 7987             102    34
# 5104             159    34
# 13116            179    34
# 15910            189    34
# 14753            122    35
# 3228             207    35
# 13356             67    35
# 3606              72    35
# 8338             148    36
# 18377            220    36
# 11862             11    36
# 6031             170    36
# 9092             174    36
# 598              236    36
# 11636             95    36
# 13186            131    36
# 17464            181    36
# 6596             195    36
# 14754            122    37
# 16978            188    37
# 15911            189    37
# 1718              78    37
# 8694              28    37
# 7988             102    38
#
# [236 rows x 16 columns]

# %%
years = list(range(df_tmv.date.dt.year.min(), df_tmv.date.dt.year.max()+1))
num_years = len(years)

np.random.seed(42)
rw = np.cumsum(np.random.normal(scale=.2, size=num_years))
rw = np.exp(rw)
goals = np.array([np.random.poisson(rw[year]) for year in range(num_years)])
plt.plot(goals);

# %%
with pm.Model() as simulated_model:
    years = list(range(df_tmv.date.dt.year.min(), df_tmv.date.dt.year.max()+1))
    num_years = len(years)

    
    step_size = pm.Lognormal('step_size', mu=.1, sd=.2, shape=1)
    
    atts_star = pm.GaussianRandomWalk('atts_star', sd=step_size, shape=num_years)
    
    home_theta = tt.exp(atts_star)
    

    # likelihood of observed data
    home_points = pm.Poisson('home_points', mu=home_theta, observed=goals)

# %%
with simulated_model:
    trace = pm.sample(tune=1000, draws=500, ncores=4)
    pm.traceplot(trace);
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /Users/kristomi/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pymc3/model.py:384: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(var.dtype, float):
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [atts_star, step_size_log__]
# 100%|██████████| 1500/1500 [00:03<00:00, 417.08it/s]

# %%
for pars in trace['atts_star']:
    plt.plot(years, np.exp(pars), 'b', alpha=.05);
plt.plot(years, goals, 'r');

# %% [markdown]
# ### On real data - attacks only

# %%
included_teams = ['England', 'Brazil', 'South Korea']
df_tmv = (df
          .copy()
          .query("date.dt.year >= 1980")
          .query("home_team in @included_teams")
          .assign(year = lambda df: df.date.dt.year - df.date.dt.year.min())
          .assign(home_team_idx = lambda df: df.home_team.apply(lambda team: included_teams.index(team)))
          .sort_values(by='date', ascending=True)
         )
df_tmv
# Out:
#             date    home_team             away_team  home_score  away_score  \
# 7325  1980-02-06      England               Ireland           2           0
# 12210 1980-05-09  South Korea            Luxembourg           2           3
# 10829 1980-05-13      England             Argentina           3           1
# 12211 1980-05-14  South Korea            Luxembourg           3           0
# 915   1980-05-20      England      Northern Ireland           1           1
# 17926 1980-06-08       Brazil                Mexico           2           0
# 9258  1980-06-15       Brazil                Russia           1           2
# 12651 1980-06-24       Brazil                 Chile           2           1
# 7086  1980-06-29       Brazil                Poland           1           1
# 29874 1980-08-23  South Korea              Malaysia           2           0
# 25967 1980-08-25  South Korea             Indonesia           3           0
# 28349 1980-08-27  South Korea              Thailand           4           0
# 5724  1980-08-27       Brazil               Uruguay           1           0
# 27403 1980-08-29  South Korea               Bahrain           5           0
# 25968 1980-09-02  South Korea             Indonesia           2           0
# 5101  1980-09-10      England                Norway           4           0
# 26175 1980-09-24  South Korea  United Arab Emirates           4           1
# 23906 1980-09-28  South Korea             Korea DPR           2           1
# 18861 1980-10-30       Brazil              Paraguay           6           0
# 3222  1980-11-19      England           Switzerland           2           1
# 3443  1980-12-21       Brazil           Switzerland           2           0
# 1967  1981-01-07       Brazil               Germany           4           1
# 12652 1981-03-14       Brazil                 Chile           2           1
# 24387 1981-03-22       Brazil               Bolivia           3           1
# 6591  1981-03-25      England                 Spain           1           2
# 24579 1981-03-29       Brazil             Venezuela           5           0
# 29875 1981-04-21  South Korea              Malaysia           2           1
# 28350 1981-04-24  South Korea              Thailand           5           1
# 10111 1981-04-29      England               Romania           0           0
# 8684  1981-05-12      England                Brazil           0           1
# ...          ...          ...                   ...         ...         ...
# 9092  2016-06-11      England                Russia           1           1
# 9756  2016-06-12       Brazil                  Peru           0           1
# 598   2016-06-16      England                 Wales           2           1
# 11636 2016-06-27      England               Iceland           1           2
# 23096 2016-09-01  South Korea                 China           3           2
# 12349 2016-09-06       Brazil              Colombia           2           1
# 24394 2016-10-06       Brazil               Bolivia           5           0
# 16810 2016-10-06  South Korea                 Qatar           3           2
# 13186 2016-10-08      England                 Malta           2           0
# 11056 2016-11-10       Brazil             Argentina           3           0
# 1305  2016-11-11  South Korea                Canada           2           0
# 17464  FIFA World Cup qualification          London         England    False
# 6596                       Friendly          London         England    False
# 27604  FIFA World Cup qualification           Seoul  Korea Republic    False
# 12350                      Friendly  Rio de Janeiro          Brazil    False
# 14754  FIFA World Cup qualification          London         England    False
# 18880  FIFA World Cup qualification       São Paulo          Brazil    False
# 30700  FIFA World Cup qualification           Seoul  Korea Republic    False
# 20748  FIFA World Cup qualification    Porto Alegre          Brazil    False
# 24829  FIFA World Cup qualification           Seoul  Korea Republic    False
# 16978  FIFA World Cup qualification          London         England    False
# 15911  FIFA World Cup qualification          London         England    False
# 12673  FIFA World Cup qualification       São Paulo          Brazil    False
# 14333                      Friendly            Biel     Switzerland     True
# 12486                      Friendly           Suwon  Korea Republic    False
# 1718                       Friendly          London         England    False
# 8694                       Friendly          London         England    False
# 16713                      Friendly           Ulsan  Korea Republic    False
# 23097             EAFF Championship           Chōfu           Japan     True
# 7988                       Friendly          London         England    False
#
#        total_goals  abs_goal_diff  home_win  away_win  home_team_idx  \
# 7325             2              2      True     False              0
# 12210            5              1     False      True              2
# 10829            4              2      True     False              0
# 12211            3              3      True     False              2
# 915              2              0     False     False              0
# 17926            2              2      True     False              1
# 9258             3              1     False      True              1
# 12651            3              1      True     False              1
# 7086             2              0     False     False              1
# 29874            2              2      True     False              2
# 25967            3              3      True     False              2
# 28349            4              4      True     False              2
# 5724             1              1      True     False              1
# 27403            5              5      True     False              2
# 25968            2              2      True     False              2
# 5101             4              4      True     False              0
# 26175            5              3      True     False              2
# 23906            3              1      True     False              2
# 18861            6              6      True     False              1
# 3222             3              1      True     False              0
# 3443             2              2      True     False              1
# 1967             5              3      True     False              1
# 12652            3              1      True     False              1
# 24387            4              2      True     False              1
# 6591             3              1     False      True              0
# 24579            5              5      True     False              1
# 29875            3              1      True     False              2
# 28350            6              4      True     False              2
# 10111            0              0     False     False              0
# 8684             1              1     False      True              0
# ...            ...            ...       ...       ...            ...
# 9092             2              0     False     False              0
# 9756             1              1     False      True              1
# 598              3              1      True     False              0
# 11636            3              1     False      True              0
# 23096            5              1      True     False              2
# 12349            3              1      True     False              1
# 24394            5              5      True     False              1
# 16810            5              1      True     False              2
# 13186            2              2      True     False              0
# 11056            3              3      True     False              1
# 1305             2              2      True     False              2
# 17464            3              3      True     False              0
# 6596             4              0     False     False              0
# 27604            3              1      True     False              2
# 12350            1              1      True     False              1
# 14754            2              2      True     False              0
# 18880            3              3      True     False              1
# 30700            1              1      True     False              2
# 20748            2              2      True     False              1
# 24829            0              0     False     False              2
# 16978            3              1      True     False              0
# 15911            1              1      True     False              0
# 12673            3              3      True     False              1
# 14333            4              2     False      True              2
# 12486            3              1      True     False              2
# 1718             0              0     False     False              0
# 8694             0              0     False     False              0
# 16713            2              0     False     False              2
# 23097            4              0     False     False              2
# 7988             2              0     False     False              0
#
#        away_team_idx  year
# 7325             100     0
# 12210            123     0
# 10829              8     0
# 12211            123     0
# 915              157     0
# 17926            137     0
# 9258             174     0
# 12651             42     0
# 7086             169     0
# 29874            128     0
# 25967             97     0
# 28349            214     0
# 5724             228     0
# 27403             15     0
# 25968             97     0
# 5101             159     0
# 26175            227     0
# 23906            111     0
# 18861            166     0
# 3222             207     0
# 3443             207     0
# 1967              78     1
# 12652             42     1
# 24387             24     1
# 6591             195     1
# 24579            232     1
# 29875            128     1
# 28350            214     1
# 10111            173     1
# 8684              28     1
# ...              ...   ...
# 9092             174    36
# 9756             167    36
# 598              236    36
# 11636             95    36
# 23096             43    36
# 12349             44    36
# 24394             24    36
# 16810            172    36
# 13186            131    36
# 11056              8    36
# 1305              37    36
# 17464            181    36
# 6596             195    36
# 27604            229    36
# 12350             44    37
# 14754            122    37
# 18880            166    37
# 30700            208    37
# 20748             61    37
# 24829             98    37
# 16978            188    37
# 15911            189    37
# 12673             42    37
# 14333            144    37
# 12486             44    37
# 1718              78    37
# 8694              28    37
# 16713            183    37
# 23097             43    37
# 7988             102    38
#
# [836 rows x 16 columns]

# %%
with pm.Model() as time_varying_model:
    years = list(range(df_tmv.date.dt.year.min(), df_tmv.date.dt.year.max()+1))
    num_years = len(years)

    num_teams = len(included_teams)
    
    sd_mu = pm.Lognormal('sd_mu', mu=.1, sd=.3)
    
    step_size = pm.Lognormal('step_size', mu=sd_mu, sd=.2, shape=num_teams)
    
    atts_star = pm.GaussianRandomWalk('atts_star', sd=step_size, shape=(num_years, num_teams))
    
    home_theta = tt.exp(atts_star[df_tmv.year.values, df_tmv.home_team_idx.values])
    

    # likelihood of observed data
    home_points = pm.Poisson('home_points', mu=home_theta, observed=df_tmv.home_score.values)

# %%
with time_varying_model:
    trace = pm.sample(tune=1000, draws=500, ncores=4)
    pm.traceplot(trace, combined=True);
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /Users/kristomi/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pymc3/model.py:384: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(var.dtype, float):
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [atts_star, step_size_log__, sd_mu_log__]
# 100%|██████████| 1500/1500 [00:52<00:00, 28.52it/s]
# The estimated number of effective samples is smaller than 200 for some parameters.

# %% [markdown]
# Teams ranked by attacking strength

# %%
(pd
 .DataFrame(trace['atts_star'][-1, :], columns=included_teams)
 .agg(['mean', 'median', 'std'])
 .T
 .sort_values(by='median', ascending=False)
)
# Out:
#              mean  median  std
# Brazil       0.89    0.90 0.03
# England      0.55    0.57 0.09
# South Korea  0.54    0.55 0.05

# %%
colors = ['b', 'g', 'r']
goals_avg = df_tmv.groupby(['year', 'home_team_idx'])['home_score'].mean().unstack()
for team in df_tmv.home_team_idx.unique():
    for pars in trace['atts_star']:
        plt.plot(years, np.exp(pars[:,team]), colors[team], alpha=.02);
for team in df_tmv.home_team_idx.unique():
    plt.plot(years, goals_avg[team].values, colors[team]);

# %% [markdown]
# ### Time-varying parameters, also with defense

# %%
(df
 .assign(antall=1)
 .groupby('home_team')
 ['antall']
 .sum()
 .sort_values(ascending=False)
 .head(5)
)
# Out:
# home_team
# Brazil       548
# Argentina    532
# Germany      492
# Mexico       491
# England      479
# Name: antall, dtype: int64

# %%
included_teams = ['Argentina', 'Brazil', 'Germany']
df_tmv = (df
          .copy()
          .query("home_team in @included_teams")
          .query("away_team in @included_teams")
# 10955 2014-07-13    Germany  Argentina           1           0
# 10956 2014-09-03    Germany  Argentina           2           4
# 8803  2014-10-11  Argentina     Brazil           0           2
# 8804  2015-11-13  Argentina     Brazil           1           1
# 11056 2016-11-10     Brazil  Argentina           3           0
# 8805  2017-06-09  Argentina     Brazil           1           0
# 8851  2018-03-27    Germany     Brazil           0           1
#
#                          tournament               city       country  neutral  \
# 8749                       Friendly       Buenos Aires     Argentina    False
# 8750                      Copa Roca       Buenos Aires     Argentina    False
# 8751                   Copa América       Buenos Aires     Argentina    False
# 8752                   Copa América         Montevideo       Uruguay     True
# 11012                  Copa América     Rio de Janeiro        Brazil    False
# 11013                      Friendly     Rio de Janeiro        Brazil    False
# 8753                   Copa América       Viña del Mar         Chile     True
# 8754                   Copa América       Buenos Aires     Argentina    False
# 11014                  Copa América     Rio de Janeiro        Brazil    False
# 11015                     Copa Roca          São Paulo        Brazil    False
# 8755                   Copa América         Montevideo       Uruguay     True
# 8756                       Friendly       Buenos Aires     Argentina    False
# 8757                      Copa Roca       Buenos Aires     Argentina    False
# 8758                   Copa América       Buenos Aires     Argentina    False
# 8759                   Copa América       Buenos Aires     Argentina    False
# 8760                   Copa América       Buenos Aires     Argentina    False
# 8761                   Copa América       Buenos Aires     Argentina    False
# 11016                     Copa Roca     Rio de Janeiro        Brazil    False
# 11017                     Copa Roca     Rio de Janeiro        Brazil    False
# 11018                     Copa Roca          São Paulo        Brazil    False
# 11019                     Copa Roca          São Paulo        Brazil    False
# 8762                      Copa Roca       Buenos Aires     Argentina    False
# 8763                      Copa Roca       Buenos Aires     Argentina    False
# 8764                      Copa Roca         Avellaneda     Argentina    False
# 8765                   Copa América         Montevideo       Uruguay     True
# 8766                   Copa América           Santiago         Chile     True
# 11020                     Copa Roca          São Paulo        Brazil    False
# 11021                     Copa Roca     Rio de Janeiro        Brazil    False
# 11022                     Copa Roca     Rio de Janeiro        Brazil    False
# 8767                   Copa América       Buenos Aires     Argentina    False
# ...                             ...                ...           ...      ...
# 11050  FIFA World Cup qualification     Belo Horizonte        Brazil    False
# 8796                   Copa América               Lima          Peru     True
# 8848                       Friendly             Berlin       Germany    False
# 10950                      Friendly         Düsseldorf       Germany    False
# 8797   FIFA World Cup qualification       Buenos Aires     Argentina    False
# 10951            Confederations Cup          Nuremberg       Germany    False
# 8849             Confederations Cup          Nuremberg       Germany    False
# 11051            Confederations Cup  Frankfurt am Main       Germany     True
# 10952                FIFA World Cup             Berlin       Germany    False
# 8798                       Friendly             London       England     True
# 11052                  Copa América          Maracaibo     Venezuela     True
# 8799   FIFA World Cup qualification            Rosario     Argentina    False
# 10953                      Friendly             Munich       Germany    False
# 1792                 FIFA World Cup          Cape Town  South Africa     True
# 8800                       Friendly               Doha         Qatar     True
# 8850                       Friendly          Stuttgart       Germany    False
# 8801                       Friendly            Córdoba     Argentina    False
# 11053                      Friendly              Belém        Brazil    False
# 11054                      Friendly    East Rutherford           USA     True
# 10954                      Friendly  Frankfurt am Main       Germany    False
# 11055                      Friendly            Goiânia        Brazil    False
# 8802                       Friendly       Buenos Aires     Argentina    False
# 1973                 FIFA World Cup     Belo Horizonte        Brazil    False
# 10955                FIFA World Cup     Rio de Janeiro        Brazil     True
# 10956                      Friendly         Düsseldorf       Germany    False
# 8803                       Friendly            Beijing         China     True
# 8804   FIFA World Cup qualification       Buenos Aires     Argentina    False
# 11056  FIFA World Cup qualification     Belo Horizonte        Brazil    False
# 8805                       Friendly          Melbourne     Australia     True
# 8851                       Friendly             Berlin       Germany    False
#
#        total_goals  abs_goal_diff  home_win  away_win  home_team_idx  \
# 8749             3              3      True     False              0
# 8750             1              1     False      True              0
# 8751             2              0     False     False              0
# 8752             6              2      True     False              0
# 11012            4              2      True     False              1
# 11013            6              0     False     False              1
# 8753             2              2      True     False              0
# 8754             1              1      True     False              0
# 11014            2              2      True     False              1
# 11015            3              1      True     False              1
# 8755             3              1      True     False              0
# 8756             2              2     False      True              0
# 8757             2              2      True     False              0
# 8758             5              3      True     False              0
# 8759             4              0     False     False              0
# 8760             1              1      True     False              0
# 8761             2              2      True     False              0
# 11016            6              4     False      True              1
# 11017            5              1      True     False              1
# 11018            4              0     False     False              1
# 11019            3              3     False      True              1
# 8762             7              5      True     False              0
# 8763             5              1     False      True              0
# 8764             6              4      True     False              0
# 8765             3              1      True     False              0
# 8766             4              2      True     False              0
# 11020            7              1     False      True              1
# 11021            8              4      True     False              1
# 11022            4              2      True     False              1
# 8767             2              2      True     False              0
# ...            ...            ...       ...       ...            ...
# 11050            4              2      True     False              1
# 8796             4              0     False     False              0
# 8848             2              0     False     False              2
# 10950            4              0     False     False              2
# 8797             4              2      True     False              0
# 10951            4              0     False     False              2
# 8849             5              1     False      True              2
# 11051            5              3      True     False              1
# 10952            2              0     False     False              2
# 8798             3              3     False      True              0
# 11052            3              3      True     False              1
# 8799             4              2     False      True              0
# 10953            1              1     False      True              2
# 1792             4              4     False      True              0
# 8800             1              1      True     False              0
# 8850             5              1      True     False              2
# 8801             0              0     False     False              0
# 11053            2              2      True     False              1
# 11054            7              1     False      True              1
# 10954            4              2     False      True              2
# 11055            3              1      True     False              1
# 8802             3              1      True     False              0
# 1973             8              6     False      True              1
# 10955            1              1      True     False              2
# 10956            6              2     False      True              2
# 8803             2              2     False      True              0
# 8804             2              0     False     False              0
# 11056            3              3      True     False              1
# 8805             1              1      True     False              0
# 8851             1              1     False      True              2
#
#        away_team_idx  year
# 8749               1     0
# 8750               1     0
# 8751               1     2
# 8752               1     3
# 11012              0     5
# 11013              0     5
# 8753               1     6
# 8754               1     7
# 11014              0     8
# 11015              0     8
# 8755               1     9
# 8756               1     9
# 8757               1     9
# 8758               1    11
# 8759               1    11
# 8760               1    23
# 8761               1    23
# 11016              0    25
# 11017              0    25
# 11018              0    26
# 11019              0    26
# 8762               1    26
# 8763               1    26
# 8764               1    26
# 8765               1    28
# 8766               1    31
# 11020              0    31
# 11021              0    31
# 11022              0    31
# 8767               1    32
# ...              ...   ...
# 11050              0    90
# 8796               1    90
# 8848               1    90
# 10950              0    91
# 8797               1    91
# 10951              0    91
# 8849               1    91
# 11051              0    91
# 10952              0    92
# 8798               1    92
# 11052              0    93
# 8799               1    95
# 10953              0    96
# 1792               2    96
# 8800               1    96
# 8850               1    97
# 8801               1    97
# 11053              0    97
# 11054              0    98
# 10954              0    98
# 11055              0    98
# 8802               1    98
# 1973               2   100
# 10955              0   100
# 10956              0   100
# 8803               1   100
# 8804               1   101
# 11056              0   102
# 8805               1   103
# 8851               1   104
#
# [147 rows x 16 columns]

# %%
with pm.Model() as time_varying_model:
    years = list(range(df_tmv.date.dt.year.min(), df_tmv.date.dt.year.max()+1))
    num_years = len(years)

    num_teams = len(included_teams)
    
    sd_mu = pm.Lognormal('sd_mu', mu=.1, sd=.3)
    
    step_size = pm.Lognormal('step_size', mu=sd_mu, sd=.2, shape=num_teams)
    
    atts_star = pm.GaussianRandomWalk('atts_star', sd=step_size, shape=(num_years, num_teams))
    defs_star = pm.GaussianRandomWalk('defs_star', sd=step_size, shape=(num_years, num_teams))
    
    home = pm.Flat('home')
    intercept = pm.Flat('intercept')
    
    home_theta = tt.exp(intercept + home + atts_star[df_tmv.year.values, df_tmv.home_team_idx.values]
                       + defs_star[df_tmv.year.values, df_tmv.away_team_idx.values])
    #away_theta = tt.exp(intercept + atts_star[df_tmv.year.values, df_tmv.away_team_idx.values]
                        #+ defs_star[df_tmv.year.values, df_tmv.home_team_idx.values])    


    # likelihood of observed data
    home_points = pm.Poisson('home_points', mu=home_theta, observed=df_tmv.home_score.values)
    #away_points = pm.Poisson('away_points', mu=away_theta, observed=df_tmv.away_score.values)

# %% [markdown]
# https://discourse.pymc.io/t/prediction-using-sample-ppc-in-hierarchical-model/116
# https://github.com/pymc-devs/pymc3/issues/1001

# %%
with time_varying_model:
    trace = pm.sample(tune=1000, draws=500, ncores=4)
    pm.traceplot(trace, combined=True);
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /Users/kristomi/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pymc3/model.py:384: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(var.dtype, float):
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [intercept, home, defs_star, atts_star, step_size_log__, sd_mu_log__]
# 100%|██████████| 1500/1500 [03:55<00:00,  6.37it/s]
# The chain contains only diverging samples. The model is probably misspecified.
# The acceptance probability does not match the target. It is 0.0, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain contains only diverging samples. The model is probably misspecified.
# The acceptance probability does not match the target. It is 0.10805779585373043, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain contains only diverging samples. The model is probably misspecified.
# The acceptance probability does not match the target. It is 0.0, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain contains only diverging samples. The model is probably misspecified.
# The acceptance probability does not match the target. It is 0.04536745841695545, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
(pd
 .DataFrame(trace['atts_star'][-1, :], columns=included_teams)
 .agg(['mean', 'median', 'std'])
 .T
 .sort_values(by='median', ascending=False)
)
# Out:
#              mean  median  std
# Brazil       0.76    0.75 0.02
# England      0.67    0.66 0.06
# South Korea  0.62    0.63 0.07

# %%
colors = ['b', 'g', 'r']
goals_avg = df_tmv.groupby(['year', 'home_team_idx'])['home_score'].mean().unstack()
for team in df_tmv.home_team_idx.unique():
    for pars in trace['atts_star']:
        plt.plot(years, np.exp(pars[:,team]), colors[team], alpha=.02);
for team in df_tmv.home_team_idx.unique():
    plt.plot(years, goals_avg[team].values, colors[team]);
