# %% [markdown]
# # World cup 2018 model

# %% [markdown]
# Importerer pakker

# %%
import pandas as pd
import pickle
import os
import itertools as it
from pathlib import Path
import matplotlib.pyplot as plt
from IPython.display import HTML

import menon_styles



#%load_ext autoreload
#%autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('float_format', '{:.2f}'.format)

ROOT_DIR = Path(os.environ.get('ROOT_DIR'))
DATA_DIR = ROOT_DIR / 'data'

# %%
menon_styles.menon_styles()
# Out:
# <style>
# html {
#   font-size: 62.5% !important;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
# }
# tr:nth-child(2) tr:hover {
#   background: yellow;
# }
#
# div.text_cell_render {
#     font-family: Calibri, sans-serif !important;
#     font-size: 10pt;
# }
# .text_cell.rendered h1, h2, h3, h4 {
#   font-family: Calibri, sans-serif !important;
# 	margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: bold !important; }
# .text_cell.rendered h1 {
#   font-size: 30pt;
# }
# .text_cell.rendered h2 {
# 	font-size: 24pt;
#   color: rgb(57,87,117);
# }
# .text_cell.rendered h3 {
# 	font-size: 20pt;
#   color: rgb(214,127,22);
# }
# .text_cell.rendered h4 {
# 	font-size: 14pt;
#   color: rgb(57,87,117);
# }
# </style>
#
#
# <style>
# h1:after {
#     content: url('https://www.menon.no/wp-content/uploads/2017logo@2x.png');
#     float: right;
# }
# </style>

# %% [markdown]
# ## En overskrift

# %%
from src.tournament import *
from src.empirical_models.elo import Elo, TeamElo
from src.empirical_models.regression import ConstantPar
from src.make_data import make_groups
# Out:
# /Users/kristomi/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#e = Elo();
#e.train();
#e.save()

# %%
e = pickle.loads((DATA_DIR / 'models/elo_pickle.pkl').read_bytes())

# %%
wc = WorldCup(e)
wc.group_outcome.query("group == 'C'")
# Out:
#    group       team  goals_scored  goals_admitted  points  goals_diff  rank
# 10     C     France             1               0       5           1     1
# 11     C       Peru             1               1       4           0     2
# 9      C    Denmark             0               0       3           0     3
# 8      C  Australia             0               1       2          -1     4

# %%
wc.games
# Out:
#             home home_score away_score          away str_score
# 0         Russia          0          1  Saudi Arabia        01
# 1          Egypt          0          0       Uruguay        00
# 2        Morocco          1          0          Iran        10
# 3       Portugal          0          1         Spain        01
# 4         France          0          0     Australia        00
# 5      Argentina          1          0       Iceland        10
# 6           Peru          0          0       Denmark        00
# 7        Croatia          1          0       Nigeria        10
# 8     Costa Rica          0          1        Serbia        01
# 9        Germany          0          0        Mexico        00
# 10        Brazil          1          0   Switzerland        10
# 11        Sweden          0          1   South Korea        01
# 12       Belgium          0          0        Panama        00
# 13       Tunisia          0          1       England        01
# 14      Colombia          0          0         Japan        00
# 15        Poland          0          1       Senegal        01
# 16        Russia          0          1         Egypt        01
# 17      Portugal          1          0       Morocco        10
# 18       Uruguay          0          0  Saudi Arabia        00
# 19          Iran          0          1         Spain        01
# 20       Denmark          0          0     Australia        00
# 21        France          1          0          Peru        10
# 22     Argentina          0          0       Croatia        00
# 23        Brazil          1          0    Costa Rica        10
# 24       Nigeria          0          0       Iceland        00
# 25        Serbia          0          1   Switzerland        01
# 26       Belgium          1          0       Tunisia        10
# 27   South Korea          0          1        Mexico        01
# 28       Germany          0          0        Sweden        00
# 29       England          1          0        Panama        10
# ..           ...        ...        ...           ...       ...
# 34         Spain          1          0       Morocco        10
# 35          Iran          0          0      Portugal        00
# 36       Denmark          0          0        France        00
# 37     Australia          0          1          Peru        01
# 38       Nigeria          0          1     Argentina        01
# 39       Iceland          0          1       Croatia        01
# 40   South Korea          0          1       Germany        01
# 41        Mexico          1          0        Sweden        10
# 42        Serbia          0          1        Brazil        01
# 43   Switzerland          0          1    Costa Rica        01
# 44         Japan          0          1        Poland        01
# 45       Senegal          1          0      Colombia        10
# 46       England          1          0       Belgium        10
# 47        Panama          0          0       Tunisia        00
# 49  Saudi Arabia          1          0      Portugal        10
# 50        France          0          1       Croatia        01
# 51         Spain          0          1       Uruguay        01
# 52     Argentina          1          0          Peru        10
# 53        Brazil          1          0       Germany        10
# 54       England          1          0        Poland        10
# 55        Mexico          0          1    Costa Rica        01
# 56       Senegal          0          1       Belgium        01
# 57  Saudi Arabia          0          1       Croatia        01
# 58        Brazil          1          0       England        10
# 59       Uruguay          0          1     Argentina        01
# 60    Costa Rica          1          0       Belgium        10
# 61       Croatia          0          1        Brazil        01
# 62     Argentina          0          1    Costa Rica        01
# 63       Croatia          0          1     Argentina        01
# 64        Brazil          1          0    Costa Rica        10
#
# [64 rows x 5 columns]

# %%
wc_teams = list(it.chain.from_iterable(make_groups().values()))
df = e.teams_df[wc_teams]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
df.tail(20).plot(ax=ax, title='Elos over time for WC countries');
#ax.legend(frameon=False, loc='right', ncol=16)
ax.set_ylabel('Elo');

# %%
fig, ax = plt.subplots(figsize=(10, 8))
df.T[list(df.T)[-1]].sort_values(ascending=False).plot(kind='barh', ax=ax);

# %%
sim = Simulation([e], n=100)

# %%
sim.str_scores.T[0].value_counts()
# Out:
# 10    49
# 01    33
# 00    18
# Name: 0, dtype: int64

# %%
def mode_and_share(ser):
    lambda ser: ser.value_counts(normalize=True).index[0]

sim.str_scores.T.map()
# Out:
# 0     10
# 1     00
# 2     01
# 3     01
# 4     00
# 5     10
# 6     01
# 7     10
# 8     01
# 9     00
# 10    10
# 11    01
# 12    10
# 13    01
# 14    10
# 15    01
# 16    01
# 17    10
# 18    00
# 19    01
# 20    01
# 21    10
# 22    10
# 23    00
# 24    01
# 25    10
# 26    10
# 27    01
# 28    00
# 29    10
#       ..
# 34    10
# 35    01
# 36    00
# 37    01
# 38    01
# 39    01
# 40    01
# 41    10
# 42    01
# 43    01
# 44    00
# 45    01
# 46    10
# 47    01
# 49    01
# 50    10
# 51    10
# 52    01
# 53    01
# 54    01
# 55    10
# 56    10
# 57    10
# 58    10
# 59    01
# 60    01
# 61    01
# 62    10
# 63    10
# 64    10
# Length: 64, dtype: object

# %%
sim.style
# Out:
# <style  type="text/css" >
#     #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col0 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col1 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col2 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col3 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col4 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col5 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col6 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col7 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col8 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 0%);
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 0%);
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row0_col11 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 0%);
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col0 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col1 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col2 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col3 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col4 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col5 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col6 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col7 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col8 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col9 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col10 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row1_col11 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 0%);
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col0 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col1 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col2 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col3 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col4 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col5 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col6 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col7 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col8 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col9 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col10 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row2_col11 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col0 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col1 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col2 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col3 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col4 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col5 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col6 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col7 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col8 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col9 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col10 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row3_col11 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col0 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col1 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col2 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col3 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col4 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col5 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col6 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col7 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col8 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col9 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col10 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row4_col11 {
#             width:  10em;
#              height:  80%;
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col0 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col1 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col2 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col3 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col4 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col5 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col6 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col7 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col8 {
#             border-color:  black;
#         }    #T_ff9b560c_6f4e_11e8_b646_5a0048e86801row5_col9 {
#             width:  10em;

# %%
sim.group
# Out:
# <style  type="text/css" >
#     #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col0 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col1 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col2 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col3 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col4 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col5 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col6 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col7 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col8 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col9 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col10 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row0_col11 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col0 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col1 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col2 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col3 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col4 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col5 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col6 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col7 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col8 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col9 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col10 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row1_col11 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col0 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col1 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col2 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col3 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col4 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col5 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col6 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col7 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col8 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col9 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col10 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row2_col11 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col0 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col1 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col2 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col3 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col4 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col5 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col6 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col7 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col8 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col9 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col10 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row3_col11 {
#             background-color:  #a5b23f;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col0 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col1 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col2 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col3 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col4 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col5 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col6 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col7 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col8 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col9 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col10 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row4_col11 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col0 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col1 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col2 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col3 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col4 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col5 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col6 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col7 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col8 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col9 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col10 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row5_col11 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row6_col0 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row6_col1 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row6_col2 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row6_col3 {
#             background-color:  #931000;
#         }    #T_00a494fa_6f4f_11e8_b491_5a0048e86801row6_col4 {

# %%
#sim = Simulation([ConstantPar() for _ in range(5)], n=100)
#sim.group

# %%
#sim.style
