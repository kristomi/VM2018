# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from pathlib import Path
import os
import collections

ROOT_DIR = Path(os.environ.get('ROOT_DIR'))
DATA_DIR = ROOT_DIR / 'data'

from PIL import Image, ImageDraw, ImageFont
# %matplotlib inline

# %%
from src.tournament import WorldCup

# %%
e = pickle.loads((DATA_DIR / 'models/elo_pickle.pkl').read_bytes())
wc = WorldCup(e)
for game, out in wc.playoffs.items():
    print(f"{game}: {str(out)}")
# Out:
# 49: France 0 - 1 Argentina
# 50: Egypt 0 - 1 Portugal
# 51: Iran 0 - 1 Uruguay
# 52: Nigeria 0 - 1 Denmark
# 53: Brazil 1 - 0 Mexico
# 54: England 0 - 1 Colombia
# 55: Germany 1 - 0 Switzerland
# 56: Poland 0 - 1 Panama
# 57: Portugal 0 - 1 Argentina
# 58: Brazil 1 - 0 Colombia
# 59: Germany 1 - 0 Panama
# 60: Uruguay 1 - 0 Denmark
# 61: Brazil 1 - 0 Argentina
# 62: Uruguay 1 - 0 Germany
# 63: Argentina 0 - 1 Germany
# 64: Brazil 1 - 0 Uruguay

# %%
def plot_wc(bracket_dict=None, image_file=None, opacity=128):
    if bracket_dict is None:
        out = collections.namedtuple('out', 'home away home_score away_score winner')
        bracket_dict = collections.defaultdict(lambda : out('home_test', 'away_test', 1, 2, 'winner test'))

        # get an image
    if image_file is None:
        image_file = Image.open('../data/brackets/world-cup.png').convert('RGBA')

    # make a blank image for the text, initialized to transparent text color
    txt = Image.new('RGBA', image_file.size, (255,255,255,0))

    # get a font
    fnt = ImageFont.truetype("../data/brackets/Verdana.ttf",28)

    # get a drawing context
    d = ImageDraw.Draw(txt)
    group_offset = 80
    group_vertical_offset = 188
    group_cycle = 137
    quarter_offset = 335
    quarter_vertical_offset = 250
    quarter_cycle = 274
    right_edge = image_file.size[0] - 150

    # 1/8 finals
    n = 0                                                    
    for game_num in [50, 49, 53, 54]:
        home, away = bracket_dict[game_num].home, bracket_dict[game_num].away
        d.text((group_offset, group_vertical_offset + n*group_cycle), home, font=fnt, fill=(0,0,0,opacity))
        n +=1                                                 
        d.text((group_offset, group_vertical_offset + n*group_cycle), away, font=fnt, fill=(0,0,0,opacity))
        n +=1

    n = 0
    for game_num in [51, 52, 55, 56]:
        home, away = bracket_dict[game_num].home, bracket_dict[game_num].away
        d.text((right_edge - 120, group_vertical_offset + n*group_cycle), home, font=fnt, fill=(0,0,0,opacity))
        n +=1                                                 
        d.text((right_edge - 120, group_vertical_offset + n*group_cycle), away, font=fnt, fill=(0,0,0,opacity))
        n +=1

    # 1/4 finals
    n = 0
    for game_num in [57, 58]:
        home, away = bracket_dict[game_num].home, bracket_dict[game_num].away
        d.text((quarter_offset, quarter_vertical_offset + n*quarter_cycle), home, font=fnt, fill=(0,0,0,opacity))
        n +=1                                                 
        d.text((quarter_offset, quarter_vertical_offset + n*quarter_cycle), away, font=fnt, fill=(0,0,0,opacity))
        n +=1

    n = 0
    for game_num in [60, 59]:
        home, away = bracket_dict[game_num].home, bracket_dict[game_num].away
        d.text((right_edge - quarter_offset, quarter_vertical_offset + n*quarter_cycle), home, font=fnt, fill=(0,0,0,opacity))
        n +=1                                                 
        d.text((right_edge - quarter_offset, quarter_vertical_offset + n*quarter_cycle), away, font=fnt, fill=(0,0,0,opacity))
        n +=1

    # Semi finals

    home, away = bracket_dict[61].home, bracket_dict[61].away
    d.text((520, 380 + 552), home, font=fnt, fill=(0,0,0,opacity))
    d.text((520, 380), away, font=fnt, fill=(0,0,0,opacity))

    home, away = bracket_dict[62].home, bracket_dict[62].away
    d.text((right_edge - 520, 380), home, font=fnt, fill=(0,0,0,opacity))
    d.text((right_edge - 520, 380 + 552), away, font=fnt, fill=(0,0,0,opacity))    

    # Final
    semi1, semi2 = bracket_dict[64].home, bracket_dict[64].away
    d.text((610, 680), semi1, font=fnt, fill=(0,0,0,opacity))
    d.text((right_edge - 640, 680), semi2, font=fnt, fill=(0,0,0,opacity))

    winner = bracket_dict[64].winner
    d.text((720, 810), winner, font=fnt, fill=(0,0,0,opacity))

    # Bronze final
    semi1, semi2 = bracket_dict[63].home, bracket_dict[63].away
    d.text((640, 1020), semi1, font=fnt, fill=(0,0,0,opacity))
    d.text((640, 1078), away, font=fnt, fill=(0,0,0,opacity))

    # 3rd place
    d.text((right_edge - 638, 1042), bracket_dict[63].winner, font=fnt, fill=(0,0,0,opacity))

    out = Image.alpha_composite(image_file, txt)
    
    return out

out = plot_wc(wc.playoffs)

#out.show()
fig, ax = plt.subplots(figsize=(40, 10))
ax.imshow(np.asarray(out),);

# %%
stats = []
image = None
for _ in range(100):
    e = pickle.loads((DATA_DIR / 'models/elo_pickle.pkl').read_bytes())
    wc = WorldCup(e)
    stats.append(wc.stats)
    image = plot_wc(wc.playoffs, image)

fig, ax = plt.subplots(figsize=(40, 10))
ax.imshow(np.asarray(image),);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/src/datetime.pxd in datetime._string_to_dts()
#
# ValueError: Error parsing datetime string "Peru" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/.pyenv/versions/3.6.4/envs/whisky/lib/python3.6/site-packages/dateutil/parser.py in parse(timestr, parserinfo, **kwargs)
#    1181     else:
# -> 1182         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1183
#
# ~/.pyenv/versions/3.6.4/envs/whisky/lib/python3.6/site-packages/dateutil/parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     558         if res is None:
# --> 559             raise ValueError("Unknown string format")
#     560
#
# ValueError: Unknown string format
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in try_datetime(v)
#     881         try:
# --> 882             v = tslib.array_to_datetime(v, errors='raise')
#     883         except ValueError:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/.pyenv/versions/3.6.4/envs/whisky/lib/python3.6/site-packages/dateutil/parser.py in parse(timestr, parserinfo, **kwargs)
#    1181     else:
# -> 1182         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1183
#
# ~/.pyenv/versions/3.6.4/envs/whisky/lib/python3.6/site-packages/dateutil/parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     558         if res is None:
# --> 559             raise ValueError("Unknown string format")
#     560
#
# ValueError: Unknown string format
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/src/datetime.pxd in datetime._string_to_dts()
#
# ValueError: Error parsing datetime string "Peru" at position 0
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-71450aa6fa8b> in <module>()
#       3 for _ in range(100):
#       4     e = pickle.loads((DATA_DIR / 'models/elo_pickle.pkl').read_bytes())
# ----> 5     wc = WorldCup(e)
#       6     stats.append(wc.stats)
#       7     image = plot_wc(wc.playoffs, image)
#
# ~/git_prosjekter/VM2018/src/tournament.py in __init__(self, match)
#     133         self.match = match
#     134         self.group_play()
# --> 135         self.playoff()
#     136
#     137     def group_play(self):
#
# ~/git_prosjekter/VM2018/src/tournament.py in playoff(self)
#     193
#     194         # Semi finals
# --> 195         playoffs[61] = self.fix_or_new(game_num=61, home=playoffs[58].winner, away=playoffs[57].winner)
#     196         playoffs[62] = self.fix_or_new(game_num=62, home=playoffs[60].winner, away=playoffs[59].winner)
#     197
#
# ~/git_prosjekter/VM2018/src/tournament.py in fix_or_new(self, game_num, home, away)
#     168         Helper method to either read game from fixture (if played) or to simulated
#     169         """
# --> 170         game = self.fixture.to_dict(orient='index')[game_num-1]
#     171         if np.isnan(game['home_score']): # Not yet played
#     172             return self.match(home, away, can_draw=False)
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/frame.py in to_dict(self, orient, into)
#    1001                     for row in self.values]
#    1002         elif orient.lower().startswith('i'):
# -> 1003             return into_c((k, v.to_dict(into)) for k, v in self.iterrows())
#    1004         else:
#    1005             raise ValueError("orient '%s' not understood" % orient)
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    1001                     for row in self.values]
#    1002         elif orient.lower().startswith('i'):
# -> 1003             return into_c((k, v.to_dict(into)) for k, v in self.iterrows())
#    1004         else:
#    1005             raise ValueError("orient '%s' not understood" % orient)
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/frame.py in iterrows(self)
#     746         klass = self._constructor_sliced
#     747         for k, v in zip(self.index, self.values):
# --> 748             s = klass(v, index=columns, name=k)
#     749             yield k, s
#     750
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3193             subarr = _sanitize_index(data, index, copy=True)
#    3194         else:
# -> 3195             subarr = _try_cast(data, True)
#    3196
#    3197         if copy:
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/series.py in _try_cast(arr, take_fast_path)
#    3159
#    3160         try:
# -> 3161             subarr = maybe_cast_to_datetime(arr, dtype)
#    3162             if not is_extension_type(subarr):
#    3163                 subarr = np.array(subarr, dtype=dtype, copy=copy)
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in maybe_cast_to_datetime(value, dtype, errors)
#    1042         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
#    1043                                     value.dtype == np.object_)):
# -> 1044             value = maybe_infer_to_datetimelike(value)
#    1045
#    1046     return value
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#     912         value = try_datetime(v)
#     913     elif inferred_type == 'datetime':
# --> 914         value = try_datetime(v)
#     915     elif inferred_type == 'timedelta':
#     916         value = try_timedelta(v)
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in try_datetime(v)
#     888             try:
#     889                 from pandas import to_datetime
# --> 890                 return to_datetime(v)
#     891             except Exception:
#     892                 pass
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     378         result = _convert_listlike(arg, box, format, name=arg.name)
#     379     elif is_list_like(arg):
# --> 380         result = _convert_listlike(arg, box, format)
#     381     else:
#     382         result = _convert_listlike(np.array([arg]), box, format)[0]
#
# ~/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     292                     dayfirst=dayfirst,
#     293                     yearfirst=yearfirst,
# --> 294                     require_iso8601=require_iso8601
#     295                 )
#     296
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing._parse_dateabbr_string()
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     357                 raise ValueError("stray %% in format '%s'" % format) from None
#     358             _regex_cache[format] = format_regex
# --> 359     found = format_regex.match(data_string)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
#
# KeyboardInterrupt:
