# %% [markdown]
# # World cup 2018 model

# %% [markdown]
# Importerer pakker

# %%
import pandas as pd
import pickle
import numpy as np
import os
import json
import itertools as it
from pathlib import Path
import matplotlib.pyplot as plt
from IPython.display import HTML

import menon_styles



# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
pd.set_option('float_format', '{:.2f}'.format)

ROOT_DIR = Path(os.environ.get('ROOT_DIR'))
DATA_DIR = ROOT_DIR / 'data'

# %%
menon_styles.menon_styles()
# Out:
# <style>
# html {
#   font-size: 62.5% !important;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
# }
# tr:nth-child(2) tr:hover {
#   background: yellow;
# }
#
# div.text_cell_render {
#     font-family: Calibri, sans-serif !important;
#     font-size: 10pt;
# }
# .text_cell.rendered h1, h2, h3, h4 {
#   font-family: Calibri, sans-serif !important;
# 	margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: bold !important; }
# .text_cell.rendered h1 {
#   font-size: 30pt;
# }
# .text_cell.rendered h2 {
# 	font-size: 24pt;
#   color: rgb(57,87,117);
# }
# .text_cell.rendered h3 {
# 	font-size: 20pt;
#   color: rgb(214,127,22);
# }
# .text_cell.rendered h4 {
# 	font-size: 14pt;
#   color: rgb(57,87,117);
# }
# </style>
#
#
# <style>
# h1:after {
#     content: url('https://www.menon.no/wp-content/uploads/2017logo@2x.png');
#     float: right;
# }
# </style>

# %%
from src.tournament import Simulation, Outcome, WorldCup
from src.empirical_models.elo import Elo, TeamElo
from src.empirical_models.regression import ConstantPar
from src.make_data import make_groups
# Out:
# /Users/kristomi/.pyenv/versions/3.6.4/envs/default/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## En overskrift

# %%
e = pickle.loads((DATA_DIR / 'models/elo_pickle.pkl').read_bytes())

# %%
wc = WorldCup(e)
wc.winner
# Out:
# 'Brazil'

# %%
sim = Simulation([e], n=10)
sim.style

# %%
sim = Simulation([ConstantPar() for _ in range(5)], n=100)
sim.group
# Out:
# <style  type="text/css" >
#     #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col0 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col1 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col2 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col3 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col4 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col5 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col6 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col7 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col8 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col9 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col10 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row0_col11 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col0 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col1 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col2 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col3 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col4 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col5 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col6 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col7 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col8 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col9 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col10 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row1_col11 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col0 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col1 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col2 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col3 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col4 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col5 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col6 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col7 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col8 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col9 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col10 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row2_col11 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col0 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col1 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col2 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col3 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col4 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col5 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col6 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col7 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col8 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col9 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col10 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row3_col11 {
#             background-color:  #a5b23f;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col0 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col1 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col2 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col3 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col4 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col5 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col6 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col7 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col8 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col9 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col10 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row4_col11 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col0 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col1 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col2 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col3 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col4 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col5 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col6 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col7 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col8 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col9 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col10 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row5_col11 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row6_col0 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row6_col1 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row6_col2 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row6_col3 {
#             background-color:  #931000;
#         }    #T_80aca6c6_65b8_11e8_8aaf_5a0048e86801row6_col4 {

# %%
sim.style
